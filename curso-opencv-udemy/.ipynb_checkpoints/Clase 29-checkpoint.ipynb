# %%
# Deteccion de una cara en una imagen

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
rostro1 = cv2.imread('rostro1.png',0)
plt.imshow(rostro1, cmap='gray')

# %%
familia = cv2.imread('familia.png', 0)
plt.imshow(familia, cmap='gray')

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 28C8-EB52
#
#  Directorio de C:\Users\im4644508\source\repos\curso-computer-vision-platzi\curso-opencv-udemy
#
# 24/10/2025  11:27    <DIR>          .
# 20/10/2025  16:29    <DIR>          ..
# 24/10/2025  11:16    <DIR>          .ipynb_checkpoints
# 22/10/2025  16:25    <DIR>          anaconda_projects
# 22/10/2025  16:25           106.962 cara.jpg
# 22/10/2025  16:25           106.962 cara_perro.jpg
# 22/10/2025  16:28           471.903 cereal.png
# 22/10/2025  16:29         2.981.434 cereales.png
# 22/10/2025  16:25         1.075.201 Clase 25.ipynb
# 22/10/2025  16:25            56.447 Clase 26.ipynb
# 22/10/2025  16:25           523.812 Clase 27.ipynb
# 22/10/2025  16:50         2.714.334 Clase 28.ipynb
# 24/10/2025  11:27           532.210 Clase 29.ipynb
# 17/10/2025  18:18           852.684 Clase 6.ipynb
# 20/10/2025  16:29         1.622.141 Clase 7.ipynb
# 20/10/2025  16:29            52.258 Clase 8.ipynb
# 20/10/2025  16:29            52.274 Clase 9.ipynb
# 17/10/2025  13:48         5.037.488 Clase3.ipynb
# 20/10/2025  16:56               549 dibujar_en_video.py
# 24/10/2025  11:17           764.166 familia.png
# 24/10/2025  11:26               199 haarcascade_frontalface_default.xml
# 20/10/2025  16:48               395 leervideo.py
# 17/10/2025  12:53           338.879 perro.jpg
# 20/10/2025  16:29            25.874 perro_al_reves.jpg
# 20/10/2025  16:29               584 raton.py
# 20/10/2025  16:29               985 raton2.py
# 24/10/2025  11:17           278.500 rostro1.png
# 22/10/2025  16:25            23.407 tablero-ajedrez.png
# 17/10/2025  12:55         8.131.690 video.avi
# 20/10/2025  16:41               649 video.py
#               26 archivos     25.751.987 bytes
#                4 dirs  141.448.441.856 bytes libres

# %%
cascada_cara = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def detectar_cara(imagen):
    imagen1 = imagen.copy()
    rectangulos = cascada_cara.detectMultiScale(imagen1)
    for (x,y,w,h) in rectangulos:
        cv2.rectangle(imagen1, (x,y), (x+w,y+h), (255,0,0), 10)
    return imagen1

# %%
resultado = detectar_cara(rostro1)
plt.imshow(resultado, cmap='gray')

# %%
resultado = detectar_cara(familia)
plt.imshow(resultado, cmap='gray')

# %%
cascada_ojos = cv2.CascadeClassifier('haarcascade_eye.xml')

def detectar_ojos(imagen):
    imagen1 = imagen.copy()
    rectangulos = cascada_ojos.detectMultiScale(imagen1)
    for (x,y,w,h) in rectangulos:
        cv2.rectangle(imagen1, (x,y), (x+w,y+h), (255,0,0), 10)
    return imagen1

# %%
resultado = detectar_ojos(rostro1)
plt.imshow(resultado, cmap='gray')
