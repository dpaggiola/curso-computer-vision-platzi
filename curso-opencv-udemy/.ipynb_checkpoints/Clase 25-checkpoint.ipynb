# %%
# Detección de un objeto por emparejamiento de imagenes

# %%
import matplotlib.pyplot as plt
import cv2

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D8C6-92A3
#
#  Directory of C:\Users\Daniel\source\repos\curso-computer-vision-platzi\curso-opencv-udemy
#
# 21/10/2025  12:48    <DIR>          .
# 19/10/2025  22:22    <DIR>          ..
# 21/10/2025  12:48    <DIR>          .ipynb_checkpoints
# 21/10/2025  12:18    <DIR>          anaconda_projects
# 21/10/2025  12:48               337 Clase 25.ipynb
# 19/10/2025  20:49           852.974 Clase 6.ipynb
# 19/10/2025  21:07         1.621.723 Clase 7.ipynb
# 19/10/2025  21:41            52.074 Clase 8.ipynb
# 19/10/2025  21:55            51.996 Clase 9.ipynb
# 19/10/2025  20:49         5.037.880 Clase3.ipynb
# 21/10/2025  12:17               577 dibujar_en_video.py
# 21/10/2025  12:17               417 leervideo.py
# 19/10/2025  20:49           338.879 perro.jpg
# 19/10/2025  21:07            25.874 perro_al_reves.jpg
# 19/10/2025  22:21               563 raton.py
# 19/10/2025  22:41               949 raton2.py
# 21/10/2025  12:17         8.131.690 video.avi
# 21/10/2025  12:17               678 video.py
#               14 File(s)     16.116.611 bytes
#                4 Dir(s)  36.684.918.784 bytes free

# %%
imagen = cv2.imread('perro.jpg')
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
plt.imshow(imagen)

# %%
imagen_2 = cv2.imread('cara.jpg')
imagen_2 = cv2.cvtColor(imagen_2, cv2.COLOR_BGR2RGB)
plt.imshow(imagen_2)

# %%
medodo = cv2.TM_CCOEFF
resultado = cv2.matchTemplate(imagen, imagen_2, medodo)
plt.imshow(resultado)

# %%
valor_min, valor_max, pos_min, pos_max = cv2.minMaxLoc(resultado)

# %%
imagen_2.shape
# Out:
# (595, 561, 3)

# %%
alto, ancho, colores = imagen_2.shape

# %%
top_izquierda = pos_max
botton_derecha = (pos_max[0] + ancho, pos_max[1] + alto)

# %%
cv2.rectangle(imagen, top_izquierda, botton_derecha, (255,0,0), 8)
plt.imshow(imagen)
