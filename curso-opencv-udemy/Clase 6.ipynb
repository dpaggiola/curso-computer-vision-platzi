# %%
# Abrir una imagen con OpenCV

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
pwd
# Out:
# 'C:\\Users\\im4644508\\source\\repos\\curso-computer-vision-platzi\\curso-opencv-udemy'

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 28C8-EB52
#
#  Directorio de C:\Users\im4644508\source\repos\curso-computer-vision-platzi\curso-opencv-udemy
#
# 17/10/2025  17:38    <DIR>          .
# 17/10/2025  12:56    <DIR>          ..
# 17/10/2025  13:48    <DIR>          .ipynb_checkpoints
# 17/10/2025  13:48         5.037.488 Clase3.ipynb
# 17/10/2025  12:53           338.879 perro.jpg
# 17/10/2025  17:38             1.507 Untitled.ipynb
#                3 archivos      5.377.874 bytes
#                3 dirs  138.284.072.960 bytes libres

# %%
imagen = cv2.imread('perro.jpg')

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
imagen.shape
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(imagen)

# %%
# OpenCV --> BGR (Blue, Green, Red)
# Matplotlib --> RGB (Red, Green, Blue)

# %%
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen)

# %%
imagen_blanco_negro = cv2.imread('perro.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagen_blanco_negro, cmap='gray')
